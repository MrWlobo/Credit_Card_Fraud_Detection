# %% [markdown]
# # Data Cleaning Experiments
#
# Figuring out the exact process of data cleaning before implementing it as a parto of the pipeline.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from src.steps.clean_data import clean_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from src.steps.clean_data import clean_data
#
# ModuleNotFoundError: No module named 'src'

# %%
df = pd.read_csv("../data/creditcard.csv")

# %%
clean_data(df)
